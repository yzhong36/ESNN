# %%
import tensorflow as tf
import numpy as np
import sys
import random
from scipy.stats import norm
import os
from sklearn.model_selection import train_test_split
from ESNN_layers import *
import pickle

# %%
replicates = 10
dir_path = "heritability_0.05_simulation"
res_cs = []

for i in range(1,replicates + 1):

    #load example data
    X = np.loadtxt(os.path.join('data', dir_path, "".join(["ESNN_sim_X_",str(i),".txt"])))
    Y = np.loadtxt(os.path.join('data', dir_path, "".join(["ESNN_sim_Y_",str(i),".txt"])))
    X = X.astype('float32')
    Y = Y.astype('float32')
    sample_size = X.shape[0]
    all_indices = range(len(Y))
    shuffled_indices = tf.random.shuffle(all_indices)
    X, Y= tf.gather(X, shuffled_indices), tf.gather(Y, shuffled_indices)
    X, Y=X.numpy(), Y.numpy()
    X_train_raw, X_test, Y_train_raw, Y_test = train_test_split(X, Y, test_size=0.15)

    #parameters setup
    model_type = 'regression'
    reg_type = 'linear'
    L = 10 #number of models
    nsample = 100 #number of samples used for approximate expectation in ELBO
    nepoch =50 #training epoch
    input_size = X.shape[1]
    if len(Y.shape) == 1:
        output_size = 1
    else:
        output_size = Y.shape[1]

    initial_size = X.shape[1]
    hidden_sizes = [5]# a list of numbers indicate hidden sizes
    lamb = 1.0 #weight parameter in loss function
    batch_size = 500 
    sigma = 0.0001
    temperature = 0.1 #for gumbel-softmax trick
    tau = 0.3 #for scale alpha in softmax
    mini_loss = np.mean(np.square(Y_test-np.mean(Y_test, axis = 0)))*1.0 #this is used as the threshold for purity
    l = 0
    iteration = 0
    max_iter = 15

    #run lasso for init
    from sklearn.linear_model import LassoCV
    from sklearn.linear_model import MultiTaskLassoCV
    if output_size == 1:
        clf = LassoCV(cv=5, random_state=0).fit(X_train_raw, Y_train_raw)
    else:
        clf = MultiTaskLassoCV(cv=5, random_state=0).fit(X_train_raw, Y_train_raw)
    pred_train = clf.predict(X_train_raw)
    acc_train = np.mean((Y_train_raw - pred_train)**2)
    pred_test = clf.predict(X_test)
    acc_test = np.mean((Y_test - pred_test)**2)
    print(f'Lasso Regression| train {acc_train:.4f} test {acc_test:.4f}')

    ####################################NN
    ##initializations
    #if initialize with lasso coefficient
    if output_size == 1:
        init_val = np.transpose(abs(clf.coef_))
    else:
        init_val = np.mean(np.transpose(abs(clf.coef_)), axis = -1)
    init_val = init_val.astype('float32')
    init_val = np.reshape(init_val, (input_size, 1))
    init_vals = list()
    for i in range(L):
        temp_init_val = init_val
        temp_init_val = np.reshape(temp_init_val, (input_size, 1))
        init_vals.append(tf.convert_to_tensor(temp_init_val))
    #model
    all_model = list()
    model = SNN(model_type, reg_type, sigma, input_size, output_size, hidden_sizes, temperature, tau, False, init_vals[0])
    all_myloss = list()
    all_prbs = list()
    all_cs = list()
    while l<L and iteration<= max_iter:
        myloss = np.zeros((nepoch, 4))
        for epoch in range(0, nepoch):
            learning_rate = 0.005*(0.995**epoch) # for classification
            model.optimizer = tf.optimizers.Adam(lr = learning_rate)
            all_indices = range(len(Y_train_raw))
            shuffled_indices = tf.random.shuffle(all_indices)
            train_bnn(model, tf.gather(X_train_raw, shuffled_indices), tf.gather(Y_train_raw, shuffled_indices), batch_size, learning_rate, True, nsample, 0.00005, 10.0)#0.00005
            pred, nll, kl = model.call(X_train_raw, Y_train_raw, True, 100)
            if output_size == 1:
                temp_train_acc = np.mean(tf.losses.MSE(pred[:,:,0], Y_train_raw))
            else:
                temp_train_acc = np.mean(tf.losses.MSE(pred, Y_train_raw))
            pred, temp_test_nll, kl = model.call(X_test, Y_test, True, 100)
            if output_size == 1:
                temp_test_acc = np.mean(tf.losses.MSE(pred[:,:,0], Y_test))
            else:
                temp_test_acc = np.mean(tf.losses.MSE(pred, Y_test))
            elbo = nll+kl
            myloss[epoch,0] = elbo
            myloss[epoch,1] = temp_train_acc
            # myloss[epoch,2] = temp_val_acc
            myloss[epoch,2] = temp_test_acc
            print("Iteration", iteration)
            print("Train loss", temp_train_acc)
            print("l", l)
            print("mini loss", mini_loss)
            print("Test loss", temp_test_acc)
            prbs = np.asarray(tf.nn.softmax(model.bnn.w_alpha[:,0]/tau))
            print('#################################################################################################################')
            print(np.where(prbs>0.1))
            print(np.where(prbs == np.max(prbs)))
            if epoch>3 and model_type == 'regression' and temp_test_acc<mini_loss-0.05:
                break
            if epoch>10 and model_type == 'regression' and temp_test_acc<mini_loss-0.01:
                break
            if epoch > 30:
                curr_avg = np.max(myloss[epoch-2:epoch,2])
                pre_avg = np.max(myloss[epoch-4:epoch-2,2])
                if model_type == 'regression' and curr_avg>= pre_avg:
                    break
        if model_type == 'regression' and myloss[epoch,2]<=mini_loss-0.01:
            mini_loss = myloss[epoch,2]
            l += 1
            all_myloss.append(myloss)
            all_model.append(model)
            temp_prbs = np.asarray(tf.nn.softmax(model.bnn.w_alpha[:,0]/tau))
            if temp_prbs.shape[0]<initial_size:
                if len(all_cs) == 1:
                    toinsert = np.unique(all_cs[0])
                else:
                    toinsert = np.unique(np.concatenate(all_cs))
                temp_to_add = temp_prbs
                for pos in toinsert:
                    temp_to_add = np.insert(temp_to_add, pos, 1e-10)
                all_prbs.append(temp_to_add)
            else:
                temp_to_add = temp_prbs
                all_prbs.append(temp_to_add)
            #derive residuals
            pred, nll, kl = model.call(X_train_raw, Y_train_raw, True, 100)
            if output_size == 1:
                res_train = np.mean(pred[:,:,0], axis = 0) - Y_train_raw
            else:
                res_train = np.mean(pred, axis = 0) - Y_train_raw
            pred, temp_test_nll, kl = model.call(X_test, Y_test, True, 100)
            if output_size == 1:
                res_test = np.mean(pred[:,:,0], axis = 0) - Y_test
            else:
                res_test = np.mean(pred, axis = 0) - Y_test
            Y_train_raw = res_train
            Y_test = res_test
            #compute cs
            nsnp = temp_prbs.shape[0]
            for temp_j in range(nsnp):
                cs_idx = nsnp-temp_j
                if sum(np.sort(temp_prbs)[cs_idx:])>0.95:
                    break
            temp_cs = np.argsort(temp_prbs)[cs_idx:]
            if temp_cs.shape[0]>1:
                cc = np.corrcoef(np.transpose(X[:,temp_cs]))
                for k in range(cc.shape[0]):
                    cc[k][k]=0.5
            else:
                cc = 0.5
            if np.min(cc)>=0.5:
                # all_cs.append(temp_cs)
                #remove found variables
                X_train_raw = np.delete(X_train_raw, temp_cs, axis = 1)
                X_test = np.delete(X_test, temp_cs, axis = 1)
                input_size = X_train_raw.shape[1]
                #add cs with correct idx
                nsnp = temp_to_add.shape[0]
                for temp_j in range(nsnp):
                    cs_idx = nsnp-temp_j
                    if sum(np.sort(temp_to_add)[cs_idx:])>0.95:
                        break
                temp_cs = np.argsort(temp_to_add)[cs_idx:]
                all_cs.append(temp_cs)
        if len(all_cs)>0:
            temp_init_val = tf.random.truncated_normal([input_size, 1], mean=0.0, stddev=0.1, dtype=tf.dtypes.float32)
        else:
            temp_init_val = init_vals[0]
        model = SNN(model_type, reg_type, sigma, input_size, output_size, hidden_sizes, temperature, tau, False, temp_init_val)
        iteration+=1

    res_cs.append(all_cs)
# Out:
# Lasso Regression| train 0.9479 test 0.9632
# /Users/yzhong36/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Iteration 0
# Train loss 0.99860424
# l 0
# mini loss 1.0105897188186646
# Test loss 1.0114589
# #################################################################################################################
# (array([ 2, 48]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9924964
# l 0
# mini loss 1.0105897188186646
# Test loss 1.0053959
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9837674
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99812835
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9821308
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99634135
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9813585
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99502075
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9821394
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99549824
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.9808021
# l 0
# mini loss 1.0105897188186646
# Test loss 0.9943705
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.98110425
# l 0
# mini loss 1.0105897188186646
# Test loss 0.9946096
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.98184776
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99536777
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.981702
# l 0
# mini loss 1.0105897188186646
# Test loss 0.9950304
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.98102194
# l 0
# mini loss 1.0105897188186646
# Test loss 0.99561566
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 0
# Train loss 0.98142976
# l 0
# mini loss 1.0105897188186646
# Test loss 0.9951993
# #################################################################################################################
# (array([2]),)
# (array([2]),)
# Iteration 1
# Train loss 0.98058623
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99428
# #################################################################################################################
# (array([], dtype=int64),)
# (array([68]),)
# Iteration 1
# Train loss 0.9805869
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99430424
# #################################################################################################################
# (array([], dtype=int64),)
# (array([78]),)
# Iteration 1
# Train loss 0.980607
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99454206
# #################################################################################################################
# (array([], dtype=int64),)
# (array([192]),)
# Iteration 1
# Train loss 0.98072124
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99455994
# #################################################################################################################
# (array([], dtype=int64),)
# (array([130]),)
# Iteration 1
# Train loss 0.9805391
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99434364
# #################################################################################################################
# (array([], dtype=int64),)
# (array([141]),)
# Iteration 1
# Train loss 0.9807438
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943243
# #################################################################################################################
# (array([], dtype=int64),)
# (array([121]),)
# Iteration 1
# Train loss 0.98049843
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942255
# #################################################################################################################
# (array([], dtype=int64),)
# (array([54]),)
# Iteration 1
# Train loss 0.98077124
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994114
# #################################################################################################################
# (array([], dtype=int64),)
# (array([118]),)
# Iteration 1
# Train loss 0.98063916
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99458534
# #################################################################################################################
# (array([], dtype=int64),)
# (array([116]),)
# Iteration 1
# Train loss 0.9805905
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943481
# #################################################################################################################
# (array([], dtype=int64),)
# (array([52]),)
# Iteration 1
# Train loss 0.980505
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941211
# #################################################################################################################
# (array([], dtype=int64),)
# (array([124]),)
# Iteration 1
# Train loss 0.9805248
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99420375
# #################################################################################################################
# (array([], dtype=int64),)
# (array([83]),)
# Iteration 1
# Train loss 0.98049533
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941857
# #################################################################################################################
# (array([], dtype=int64),)
# (array([35]),)
# Iteration 1
# Train loss 0.98057115
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99449486
# #################################################################################################################
# (array([], dtype=int64),)
# (array([165]),)
# Iteration 1
# Train loss 0.9807043
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994213
# #################################################################################################################
# (array([], dtype=int64),)
# (array([7]),)
# Iteration 1
# Train loss 0.98054683
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99435925
# #################################################################################################################
# (array([], dtype=int64),)
# (array([191]),)
# Iteration 1
# Train loss 0.98067194
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99407506
# #################################################################################################################
# (array([], dtype=int64),)
# (array([146]),)
# Iteration 1
# Train loss 0.9806319
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941346
# #################################################################################################################
# (array([], dtype=int64),)
# (array([166]),)
# Iteration 1
# Train loss 0.9805372
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943235
# #################################################################################################################
# (array([], dtype=int64),)
# (array([107]),)
# Iteration 1
# Train loss 0.98054713
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943609
# #################################################################################################################
# (array([], dtype=int64),)
# (array([127]),)
# Iteration 1
# Train loss 0.9805017
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99430543
# #################################################################################################################
# (array([], dtype=int64),)
# (array([11]),)
# Iteration 1
# Train loss 0.9804972
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943187
# #################################################################################################################
# (array([], dtype=int64),)
# (array([48]),)
# Iteration 1
# Train loss 0.98051125
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99436426
# #################################################################################################################
# (array([], dtype=int64),)
# (array([33]),)
# Iteration 1
# Train loss 0.9805288
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99410456
# #################################################################################################################
# (array([], dtype=int64),)
# (array([60]),)
# Iteration 1
# Train loss 0.980518
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99430406
# #################################################################################################################
# (array([], dtype=int64),)
# (array([76]),)
# Iteration 1
# Train loss 0.98057467
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943185
# #################################################################################################################
# (array([], dtype=int64),)
# (array([175]),)
# Iteration 1
# Train loss 0.9805298
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942201
# #################################################################################################################
# (array([], dtype=int64),)
# (array([181]),)
# Iteration 1
# Train loss 0.98052675
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994095
# #################################################################################################################
# (array([], dtype=int64),)
# (array([137]),)
# Iteration 1
# Train loss 0.9805158
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942875
# #################################################################################################################
# (array([], dtype=int64),)
# (array([158]),)
# Iteration 1
# Train loss 0.98060477
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9945866
# #################################################################################################################
# (array([], dtype=int64),)
# (array([180]),)
# Iteration 1
# Train loss 0.980561
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942238
# #################################################################################################################
# (array([], dtype=int64),)
# (array([134]),)
# Iteration 1
# Train loss 0.9806027
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994613
# #################################################################################################################
# (array([], dtype=int64),)
# (array([26]),)
# Iteration 2
# Train loss 0.9813657
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9948916
# #################################################################################################################
# (array([], dtype=int64),)
# (array([68]),)
# Iteration 2
# Train loss 0.98053926
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943559
# #################################################################################################################
# (array([], dtype=int64),)
# (array([92]),)
# Iteration 2
# Train loss 0.9805958
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99434614
# #################################################################################################################
# (array([], dtype=int64),)
# (array([135]),)
# Iteration 2
# Train loss 0.9806197
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994316
# #################################################################################################################
# (array([], dtype=int64),)
# (array([181]),)
# Iteration 2
# Train loss 0.9806754
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9945874
# #################################################################################################################
# (array([], dtype=int64),)
# (array([122]),)
# Iteration 2
# Train loss 0.98050463
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99418426
# #################################################################################################################
# (array([], dtype=int64),)
# (array([50]),)
# Iteration 2
# Train loss 0.98064506
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99458915
# #################################################################################################################
# (array([], dtype=int64),)
# (array([174]),)
# Iteration 2
# Train loss 0.9805023
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99431705
# #################################################################################################################
# (array([], dtype=int64),)
# (array([82]),)
# Iteration 2
# Train loss 0.9806003
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943609
# #################################################################################################################
# (array([], dtype=int64),)
# (array([149]),)
# Iteration 2
# Train loss 0.9807486
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9946045
# #################################################################################################################
# (array([], dtype=int64),)
# (array([170]),)
# Iteration 2
# Train loss 0.9805151
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99424034
# #################################################################################################################
# (array([], dtype=int64),)
# (array([193]),)
# Iteration 2
# Train loss 0.9806351
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99455744
# #################################################################################################################
# (array([], dtype=int64),)
# (array([152]),)
# Iteration 2
# Train loss 0.9804991
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942138
# #################################################################################################################
# (array([], dtype=int64),)
# (array([15]),)
# Iteration 2
# Train loss 0.9805637
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99430674
# #################################################################################################################
# (array([], dtype=int64),)
# (array([126]),)
# Iteration 2
# Train loss 0.9805146
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99426025
# #################################################################################################################
# (array([], dtype=int64),)
# (array([18]),)
# Iteration 2
# Train loss 0.9806106
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941227
# #################################################################################################################
# (array([], dtype=int64),)
# (array([119]),)
# Iteration 2
# Train loss 0.9807059
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99479926
# #################################################################################################################
# (array([], dtype=int64),)
# (array([186]),)
# Iteration 2
# Train loss 0.98067755
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99424034
# #################################################################################################################
# (array([], dtype=int64),)
# (array([104]),)
# Iteration 2
# Train loss 0.98054796
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994276
# #################################################################################################################
# (array([], dtype=int64),)
# (array([121]),)
# Iteration 2
# Train loss 0.98058754
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943615
# #################################################################################################################
# (array([], dtype=int64),)
# (array([22]),)
# Iteration 2
# Train loss 0.98049897
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99414074
# #################################################################################################################
# (array([], dtype=int64),)
# (array([198]),)
# Iteration 2
# Train loss 0.98051935
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99420434
# #################################################################################################################
# (array([], dtype=int64),)
# (array([56]),)
# Iteration 2
# Train loss 0.9806187
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99428976
# #################################################################################################################
# (array([], dtype=int64),)
# (array([59]),)
# Iteration 2
# Train loss 0.98048663
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941595
# #################################################################################################################
# (array([], dtype=int64),)
# (array([55]),)
# Iteration 2
# Train loss 0.98059374
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942841
# #################################################################################################################
# (array([], dtype=int64),)
# (array([148]),)
# Iteration 2
# Train loss 0.9808166
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9946585
# #################################################################################################################
# (array([], dtype=int64),)
# (array([17]),)
# Iteration 2
# Train loss 0.98052096
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941771
# #################################################################################################################
# (array([], dtype=int64),)
# (array([142]),)
# Iteration 2
# Train loss 0.9805047
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99433076
# #################################################################################################################
# (array([], dtype=int64),)
# (array([59]),)
# Iteration 2
# Train loss 0.98053527
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943429
# #################################################################################################################
# (array([], dtype=int64),)
# (array([51]),)
# Iteration 2
# Train loss 0.9805897
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99437934
# #################################################################################################################
# (array([], dtype=int64),)
# (array([14]),)
# Iteration 2
# Train loss 0.98049796
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941539
# #################################################################################################################
# (array([], dtype=int64),)
# (array([166]),)
# Iteration 2
# Train loss 0.9804801
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99415785
# #################################################################################################################
# (array([], dtype=int64),)
# (array([194]),)
# Iteration 3
# Train loss 0.98087966
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9948323
# #################################################################################################################
# (array([], dtype=int64),)
# (array([122]),)
# Iteration 3
# Train loss 0.9805226
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942404
# #################################################################################################################
# (array([], dtype=int64),)
# (array([197]),)
# Iteration 3
# Train loss 0.98074144
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943113
# #################################################################################################################
# (array([], dtype=int64),)
# (array([93]),)
# Iteration 3
# Train loss 0.98072255
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9940892
# #################################################################################################################
# (array([], dtype=int64),)
# (array([181]),)
# Iteration 3
# Train loss 0.98065495
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942173
# #################################################################################################################
# (array([], dtype=int64),)
# (array([135]),)
# Iteration 3
# Train loss 0.98060536
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9940618
# #################################################################################################################
# (array([], dtype=int64),)
# (array([90]),)
# Iteration 3
# Train loss 0.9806028
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99413633
# #################################################################################################################
# (array([], dtype=int64),)
# (array([104]),)
# Iteration 3
# Train loss 0.98058426
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99452317
# #################################################################################################################
# (array([], dtype=int64),)
# (array([44]),)
# Iteration 3
# Train loss 0.9805536
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99410266
# #################################################################################################################
# (array([], dtype=int64),)
# (array([110]),)
# Iteration 3
# Train loss 0.9805383
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99413216
# #################################################################################################################
# (array([], dtype=int64),)
# (array([161]),)
# Iteration 3
# Train loss 0.98052675
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99410176
# #################################################################################################################
# (array([], dtype=int64),)
# (array([56]),)
# Iteration 3
# Train loss 0.98050857
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99437875
# #################################################################################################################
# (array([], dtype=int64),)
# (array([56]),)
# Iteration 3
# Train loss 0.98063153
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944202
# #################################################################################################################
# (array([], dtype=int64),)
# (array([20]),)
# Iteration 3
# Train loss 0.980605
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99418384
# #################################################################################################################
# (array([], dtype=int64),)
# (array([157]),)
# Iteration 3
# Train loss 0.98051745
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943499
# #################################################################################################################
# (array([], dtype=int64),)
# (array([49]),)
# Iteration 3
# Train loss 0.9808256
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9950151
# #################################################################################################################
# (array([], dtype=int64),)
# (array([47]),)
# Iteration 3
# Train loss 0.9805945
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99450433
# #################################################################################################################
# (array([], dtype=int64),)
# (array([107]),)
# Iteration 3
# Train loss 0.98061764
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941244
# #################################################################################################################
# (array([], dtype=int64),)
# (array([132]),)
# Iteration 3
# Train loss 0.9806002
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941065
# #################################################################################################################
# (array([], dtype=int64),)
# (array([45]),)
# Iteration 3
# Train loss 0.98056173
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99422634
# #################################################################################################################
# (array([], dtype=int64),)
# (array([82]),)
# Iteration 3
# Train loss 0.98061186
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99448776
# #################################################################################################################
# (array([], dtype=int64),)
# (array([64]),)
# Iteration 3
# Train loss 0.9805865
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9945774
# #################################################################################################################
# (array([], dtype=int64),)
# (array([65]),)
# Iteration 3
# Train loss 0.9804997
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99418706
# #################################################################################################################
# (array([], dtype=int64),)
# (array([46]),)
# Iteration 3
# Train loss 0.98056656
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944905
# #################################################################################################################
# (array([], dtype=int64),)
# (array([85]),)
# Iteration 3
# Train loss 0.9805
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99422985
# #################################################################################################################
# (array([], dtype=int64),)
# (array([189]),)
# Iteration 3
# Train loss 0.9805211
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941734
# #################################################################################################################
# (array([], dtype=int64),)
# (array([127]),)
# Iteration 3
# Train loss 0.9806973
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99433035
# #################################################################################################################
# (array([], dtype=int64),)
# (array([12]),)
# Iteration 3
# Train loss 0.9805861
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942871
# #################################################################################################################
# (array([], dtype=int64),)
# (array([22]),)
# Iteration 3
# Train loss 0.9804867
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99416107
# #################################################################################################################
# (array([], dtype=int64),)
# (array([30]),)
# Iteration 3
# Train loss 0.98048395
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99422985
# #################################################################################################################
# (array([], dtype=int64),)
# (array([23]),)
# Iteration 3
# Train loss 0.9805709
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944382
# #################################################################################################################
# (array([], dtype=int64),)
# (array([153]),)
# Iteration 3
# Train loss 0.98055875
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99416274
# #################################################################################################################
# (array([], dtype=int64),)
# (array([178]),)
# Iteration 4
# Train loss 0.9816276
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9953574
# #################################################################################################################
# (array([], dtype=int64),)
# (array([6]),)
# Iteration 4
# Train loss 0.980699
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99417424
# #################################################################################################################
# (array([], dtype=int64),)
# (array([51]),)
# Iteration 4
# Train loss 0.9808708
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9949242
# #################################################################################################################
# (array([], dtype=int64),)
# (array([131]),)
# Iteration 4
# Train loss 0.9806438
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9946455
# #################################################################################################################
# (array([], dtype=int64),)
# (array([198]),)
# Iteration 4
# Train loss 0.98053867
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943984
# #################################################################################################################
# (array([], dtype=int64),)
# (array([83]),)
# Iteration 4
# Train loss 0.9804956
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942685
# #################################################################################################################
# (array([], dtype=int64),)
# (array([18]),)
# Iteration 4
# Train loss 0.9806708
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9947001
# #################################################################################################################
# (array([], dtype=int64),)
# (array([144]),)
# Iteration 4
# Train loss 0.980532
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99428934
# #################################################################################################################
# (array([], dtype=int64),)
# (array([149]),)
# Iteration 4
# Train loss 0.98068446
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944445
# #################################################################################################################
# (array([], dtype=int64),)
# (array([19]),)
# Iteration 4
# Train loss 0.98068154
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942956
# #################################################################################################################
# (array([], dtype=int64),)
# (array([88]),)
# Iteration 4
# Train loss 0.9805754
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943526
# #################################################################################################################
# (array([], dtype=int64),)
# (array([142]),)
# Iteration 4
# Train loss 0.9806077
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99410135
# #################################################################################################################
# (array([], dtype=int64),)
# (array([121]),)
# Iteration 4
# Train loss 0.9807346
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99473286
# #################################################################################################################
# (array([], dtype=int64),)
# (array([43]),)
# Iteration 4
# Train loss 0.98049706
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942871
# #################################################################################################################
# (array([], dtype=int64),)
# (array([174]),)
# Iteration 4
# Train loss 0.9805315
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99438864
# #################################################################################################################
# (array([], dtype=int64),)
# (array([83]),)
# Iteration 4
# Train loss 0.9805526
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994167
# #################################################################################################################
# (array([], dtype=int64),)
# (array([53]),)
# Iteration 4
# Train loss 0.98063374
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941941
# #################################################################################################################
# (array([], dtype=int64),)
# (array([33]),)
# Iteration 4
# Train loss 0.9804868
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941244
# #################################################################################################################
# (array([], dtype=int64),)
# (array([112]),)
# Iteration 4
# Train loss 0.9806222
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99421
# #################################################################################################################
# (array([], dtype=int64),)
# (array([75]),)
# Iteration 4
# Train loss 0.980508
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99423385
# #################################################################################################################
# (array([], dtype=int64),)
# (array([118]),)
# Iteration 4
# Train loss 0.980568
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943791
# #################################################################################################################
# (array([], dtype=int64),)
# (array([114]),)
# Iteration 4
# Train loss 0.9806351
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941793
# #################################################################################################################
# (array([], dtype=int64),)
# (array([198]),)
# Iteration 4
# Train loss 0.98049986
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99420315
# #################################################################################################################
# (array([], dtype=int64),)
# (array([40]),)
# Iteration 4
# Train loss 0.98053795
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944483
# #################################################################################################################
# (array([], dtype=int64),)
# (array([109]),)
# Iteration 4
# Train loss 0.980512
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943454
# #################################################################################################################
# (array([], dtype=int64),)
# (array([75]),)
# Iteration 4
# Train loss 0.98051476
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99412674
# #################################################################################################################
# (array([], dtype=int64),)
# (array([182]),)
# Iteration 4
# Train loss 0.9805316
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99414957
# #################################################################################################################
# (array([], dtype=int64),)
# (array([40]),)
# Iteration 4
# Train loss 0.9804775
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942301
# #################################################################################################################
# (array([], dtype=int64),)
# (array([33]),)
# Iteration 4
# Train loss 0.98053837
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99416167
# #################################################################################################################
# (array([], dtype=int64),)
# (array([113]),)
# Iteration 4
# Train loss 0.9807009
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994544
# #################################################################################################################
# (array([], dtype=int64),)
# (array([149]),)
# Iteration 4
# Train loss 0.9807998
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941584
# #################################################################################################################
# (array([], dtype=int64),)
# (array([197]),)
# Iteration 4
# Train loss 0.9804927
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99434006
# #################################################################################################################
# (array([], dtype=int64),)
# (array([62]),)
# Iteration 5
# Train loss 0.981794
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9952343
# #################################################################################################################
# (array([], dtype=int64),)
# (array([41]),)
# Iteration 5
# Train loss 0.9806535
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942519
# #################################################################################################################
# (array([126]),)
# (array([126]),)
# Iteration 5
# Train loss 0.98070097
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99415284
# #################################################################################################################
# (array([], dtype=int64),)
# (array([158]),)
# Iteration 5
# Train loss 0.9808334
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944288
# #################################################################################################################
# (array([158]),)
# (array([158]),)
# Iteration 5
# Train loss 0.9807012
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9945156
# #################################################################################################################
# (array([], dtype=int64),)
# (array([79]),)
# Iteration 5
# Train loss 0.9807183
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9947231
# #################################################################################################################
# (array([], dtype=int64),)
# (array([155]),)
# Iteration 5
# Train loss 0.9805724
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944324
# #################################################################################################################
# (array([], dtype=int64),)
# (array([108]),)
# Iteration 5
# Train loss 0.98058057
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944905
# #################################################################################################################
# (array([], dtype=int64),)
# (array([168]),)
# Iteration 5
# Train loss 0.9805141
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943295
# #################################################################################################################
# (array([], dtype=int64),)
# (array([10]),)
# Iteration 5
# Train loss 0.9807719
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942807
# #################################################################################################################
# (array([], dtype=int64),)
# (array([3]),)
# Iteration 5
# Train loss 0.9805759
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943944
# #################################################################################################################
# (array([], dtype=int64),)
# (array([114]),)
# Iteration 5
# Train loss 0.98051554
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994144
# #################################################################################################################
# (array([], dtype=int64),)
# (array([81]),)
# Iteration 5
# Train loss 0.9805001
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994292
# #################################################################################################################
# (array([], dtype=int64),)
# (array([185]),)
# Iteration 5
# Train loss 0.98055553
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943593
# #################################################################################################################
# (array([], dtype=int64),)
# (array([122]),)
# Iteration 5
# Train loss 0.98055583
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944111
# #################################################################################################################
# (array([], dtype=int64),)
# (array([76]),)
# Iteration 5
# Train loss 0.98062074
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943096
# #################################################################################################################
# (array([], dtype=int64),)
# (array([131]),)
# Iteration 5
# Train loss 0.98050946
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943484
# #################################################################################################################
# (array([], dtype=int64),)
# (array([55]),)
# Iteration 5
# Train loss 0.9805596
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99435365
# #################################################################################################################
# (array([], dtype=int64),)
# (array([172]),)
# Iteration 5
# Train loss 0.98071986
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99480367
# #################################################################################################################
# (array([], dtype=int64),)
# (array([43]),)
# Iteration 5
# Train loss 0.98085576
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99460864
# #################################################################################################################
# (array([], dtype=int64),)
# (array([137]),)
# Iteration 5
# Train loss 0.9805568
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99411
# #################################################################################################################
# (array([], dtype=int64),)
# (array([8]),)
# Iteration 5
# Train loss 0.9805357
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941035
# #################################################################################################################
# (array([], dtype=int64),)
# (array([182]),)
# Iteration 5
# Train loss 0.98063684
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99465567
# #################################################################################################################
# (array([], dtype=int64),)
# (array([168]),)
# Iteration 5
# Train loss 0.9806244
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942098
# #################################################################################################################
# (array([], dtype=int64),)
# (array([137]),)
# Iteration 5
# Train loss 0.98049515
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942405
# #################################################################################################################
# (array([], dtype=int64),)
# (array([15]),)
# Iteration 5
# Train loss 0.980753
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99464667
# #################################################################################################################
# (array([], dtype=int64),)
# (array([154]),)
# Iteration 5
# Train loss 0.98054636
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943126
# #################################################################################################################
# (array([], dtype=int64),)
# (array([32]),)
# Iteration 5
# Train loss 0.98072106
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9946884
# #################################################################################################################
# (array([], dtype=int64),)
# (array([109]),)
# Iteration 5
# Train loss 0.9807142
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99477684
# #################################################################################################################
# (array([], dtype=int64),)
# (array([92]),)
# Iteration 5
# Train loss 0.9804777
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941947
# #################################################################################################################
# (array([], dtype=int64),)
# (array([16]),)
# Iteration 5
# Train loss 0.98053867
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99439716
# #################################################################################################################
# (array([], dtype=int64),)
# (array([103]),)
# Iteration 5
# Train loss 0.98054576
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942939
# #################################################################################################################
# (array([], dtype=int64),)
# (array([68]),)
# Iteration 5
# Train loss 0.98049957
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941531
# #################################################################################################################
# (array([], dtype=int64),)
# (array([28]),)
# Iteration 5
# Train loss 0.9806028
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99454194
# #################################################################################################################
# (array([], dtype=int64),)
# (array([80]),)
# Iteration 5
# Train loss 0.98066014
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99437284
# #################################################################################################################
# (array([], dtype=int64),)
# (array([153]),)
# Iteration 6
# Train loss 0.9808817
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99466944
# #################################################################################################################
# (array([], dtype=int64),)
# (array([54]),)
# Iteration 6
# Train loss 0.980591
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99432164
# #################################################################################################################
# (array([], dtype=int64),)
# (array([26]),)
# Iteration 6
# Train loss 0.9805943
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99457675
# #################################################################################################################
# (array([], dtype=int64),)
# (array([52]),)
# Iteration 6
# Train loss 0.9805667
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994132
# #################################################################################################################
# (array([], dtype=int64),)
# (array([177]),)
# Iteration 6
# Train loss 0.98054296
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99434024
# #################################################################################################################
# (array([], dtype=int64),)
# (array([186]),)
# Iteration 6
# Train loss 0.98066795
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99428743
# #################################################################################################################
# (array([], dtype=int64),)
# (array([121]),)
# Iteration 6
# Train loss 0.9804807
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99423826
# #################################################################################################################
# (array([], dtype=int64),)
# (array([45]),)
# Iteration 6
# Train loss 0.9805955
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99405885
# #################################################################################################################
# (array([], dtype=int64),)
# (array([47]),)
# Iteration 6
# Train loss 0.9805065
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941188
# #################################################################################################################
# (array([], dtype=int64),)
# (array([148]),)
# Iteration 6
# Train loss 0.98055327
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943612
# #################################################################################################################
# (array([], dtype=int64),)
# (array([135]),)
# Iteration 6
# Train loss 0.9805595
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9940739
# #################################################################################################################
# (array([], dtype=int64),)
# (array([114]),)
# Iteration 6
# Train loss 0.9806033
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99443984
# #################################################################################################################
# (array([], dtype=int64),)
# (array([34]),)
# Iteration 6
# Train loss 0.9808304
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994586
# #################################################################################################################
# (array([], dtype=int64),)
# (array([178]),)
# Iteration 6
# Train loss 0.9806454
# l 1
# mini loss 0.9951993227005005
# Test loss 0.994689
# #################################################################################################################
# (array([], dtype=int64),)
# (array([96]),)
# Iteration 6
# Train loss 0.980482
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9942351
# #################################################################################################################
# (array([], dtype=int64),)
# (array([94]),)
# Iteration 6
# Train loss 0.9805905
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9944955
# #################################################################################################################
# (array([], dtype=int64),)
# (array([120]),)
# Iteration 6
# Train loss 0.980485
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99413073
# #################################################################################################################
# (array([], dtype=int64),)
# (array([176]),)
# Iteration 6
# Train loss 0.98048913
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99412686
# #################################################################################################################
# (array([], dtype=int64),)
# (array([94]),)
# Iteration 6
# Train loss 0.98055536
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99406075
# #################################################################################################################
# (array([], dtype=int64),)
# (array([84]),)
# Iteration 6
# Train loss 0.9806191
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99464977
# #################################################################################################################
# (array([], dtype=int64),)
# (array([12]),)
# Iteration 6
# Train loss 0.98057336
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9943484
# #################################################################################################################
# (array([], dtype=int64),)
# (array([103]),)
# Iteration 6
# Train loss 0.9805413
# l 1
# mini loss 0.9951993227005005
# Test loss 0.9941244
# #################################################################################################################
# (array([], dtype=int64),)
# (array([11]),)
# Iteration 6
# Train loss 0.98054016
# l 1
# mini loss 0.9951993227005005
# Test loss 0.99407566
# ...
# (array([], dtype=int64),)
# (array([91]),)
# Iteration 7
# Train loss 1.0002328
# l 0
# mini loss 0.9996370673179626
# Test loss 0.999908
# #################################################################################################################
# (array([], dtype=int64),)
# (array([31]),)
# Iteration 7
# Train loss 1.0000597
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99969286
# #################################################################################################################
# (array([], dtype=int64),)
# (array([111]),)
# Iteration 8
# Train loss 1.0003352
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997476
# #################################################################################################################
# (array([], dtype=int64),)
# (array([72]),)
# Iteration 8
# Train loss 1.0002093
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998051
# #################################################################################################################
# (array([], dtype=int64),)
# (array([116]),)
# Iteration 8
# Train loss 1.0000613
# l 0
# mini loss 0.9996370673179626
# Test loss 0.999709
# #################################################################################################################
# (array([], dtype=int64),)
# (array([174]),)
# Iteration 8
# Train loss 1.0002885
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9999684
# #################################################################################################################
# (array([], dtype=int64),)
# (array([147]),)
# Iteration 8
# Train loss 1.0001229
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99973893
# #################################################################################################################
# (array([], dtype=int64),)
# (array([57]),)
# Iteration 8
# Train loss 1.0000901
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997438
# #################################################################################################################
# (array([], dtype=int64),)
# (array([65]),)
# Iteration 8
# Train loss 1.0001681
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99986315
# #################################################################################################################
# (array([], dtype=int64),)
# (array([80]),)
# Iteration 8
# Train loss 1.000284
# l 0
# mini loss 0.9996370673179626
# Test loss 1.0001067
# #################################################################################################################
# (array([], dtype=int64),)
# (array([27]),)
# Iteration 8
# Train loss 1.0001544
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99992335
# #################################################################################################################
# (array([], dtype=int64),)
# (array([127]),)
# Iteration 8
# Train loss 1.0000358
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9996668
# #################################################################################################################
# (array([], dtype=int64),)
# (array([9]),)
# Iteration 8
# Train loss 1.0001353
# l 0
# mini loss 0.9996370673179626
# Test loss 0.999695
# #################################################################################################################
# (array([], dtype=int64),)
# (array([177]),)
# Iteration 8
# Train loss 1.0002222
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998195
# #################################################################################################################
# (array([], dtype=int64),)
# (array([91]),)
# Iteration 8
# Train loss 1.0000564
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9996978
# #################################################################################################################
# (array([], dtype=int64),)
# (array([116]),)
# Iteration 8
# Train loss 1.0000798
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997721
# #################################################################################################################
# (array([], dtype=int64),)
# (array([70]),)
# Iteration 8
# Train loss 1.000123
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99972475
# #################################################################################################################
# (array([], dtype=int64),)
# (array([25]),)
# Iteration 8
# Train loss 1.0001041
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99967194
# #################################################################################################################
# (array([], dtype=int64),)
# (array([109]),)
# Iteration 8
# Train loss 1.000153
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99987966
# #################################################################################################################
# (array([], dtype=int64),)
# (array([46]),)
# Iteration 8
# Train loss 1.0000983
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99969465
# #################################################################################################################
# (array([], dtype=int64),)
# (array([190]),)
# Iteration 8
# Train loss 1.0000527
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997425
# #################################################################################################################
# (array([], dtype=int64),)
# (array([137]),)
# Iteration 8
# Train loss 1.0000986
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99979943
# #################################################################################################################
# (array([], dtype=int64),)
# (array([153]),)
# Iteration 8
# Train loss 1.0001309
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997639
# #################################################################################################################
# (array([], dtype=int64),)
# (array([52]),)
# Iteration 8
# Train loss 1.00009
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997965
# #################################################################################################################
# (array([], dtype=int64),)
# (array([122]),)
# Iteration 8
# Train loss 1.0001642
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998937
# #################################################################################################################
# (array([], dtype=int64),)
# (array([155]),)
# Iteration 8
# Train loss 1.000156
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997494
# #################################################################################################################
# (array([], dtype=int64),)
# (array([177]),)
# Iteration 8
# Train loss 1.0002557
# l 0
# mini loss 0.9996370673179626
# Test loss 1.0000491
# #################################################################################################################
# (array([], dtype=int64),)
# (array([37]),)
# Iteration 8
# Train loss 1.0001482
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9996985
# #################################################################################################################
# (array([], dtype=int64),)
# (array([23]),)
# Iteration 8
# Train loss 1.00023
# l 0
# mini loss 0.9996370673179626
# Test loss 0.99991393
# #################################################################################################################
# (array([], dtype=int64),)
# (array([130]),)
# Iteration 8
# Train loss 1.0000356
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9996798
# #################################################################################################################
# (array([], dtype=int64),)
# (array([25]),)
# Iteration 8
# Train loss 1.000543
# l 0
# mini loss 0.9996370673179626
# Test loss 1.000333
# #################################################################################################################
# (array([], dtype=int64),)
# (array([199]),)
# Iteration 8
# Train loss 1.0000365
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9996825
# #################################################################################################################
# (array([], dtype=int64),)
# (array([119]),)
# Iteration 8
# Train loss 1.0001893
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998867
# #################################################################################################################
# (array([], dtype=int64),)
# (array([192]),)
# Iteration 8
# Train loss 1.0001429
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998439
# #################################################################################################################
# (array([], dtype=int64),)
# (array([186]),)
# Iteration 8
# Train loss 1.00021
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998279
# #################################################################################################################
# (array([], dtype=int64),)
# (array([23]),)
# Iteration 8
# Train loss 1.0001765
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9998604
# #################################################################################################################
# (array([], dtype=int64),)
# (array([83]),)
# Iteration 8
# Train loss 1.0001087
# l 0
# mini loss 0.9996370673179626
# Test loss 0.999738
# #################################################################################################################
# (array([], dtype=int64),)
# (array([11]),)
# Iteration 8
# Train loss 1.0000522
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997143
# #################################################################################################################
# (array([], dtype=int64),)
# (array([61]),)
# Iteration 9
# Train loss 1.0001322
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997771
# #################################################################################################################
# (array([], dtype=int64),)
# (array([0]),)
# Iteration 9
# Train loss 1.0002085
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9997364
# #################################################################################################################
# (array([], dtype=int64),)
# (array([21]),)
# Iteration 9
# Train loss 1.0001922
# l 0
# mini loss 0.9996370673179626
# Test loss 0.9999048
# #################################################################################################################
# (array([], dtype=int64),)
# (array([122]),)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [2], line 84
#      82 shuffled_indices = tf.random.shuffle(all_indices)
#      83 train_bnn(model, tf.gather(X_train_raw, shuffled_indices), tf.gather(Y_train_raw, shuffled_indices), batch_size, learning_rate, True, nsample, 0.00005, 10.0)#0.00005
# ---> 84 pred, nll, kl = model.call(X_train_raw, Y_train_raw, True, 100)
#      85 if output_size == 1:
#      86     temp_train_acc = np.mean(tf.losses.MSE(pred[:,:,0], Y_train_raw))
#
# File ~/Desktop/rotation/ESNN/ESNN_layers.py:189, in SNN.call(self, x, y, sample, nsample)
#     187 x = tf.nn.relu(x)
#     188 for i in range(1, len(self.hidden_sizes)):
# --> 189    x = self.mylayers[i](x)
#     190    x = tf.nn.relu(x)
#     191 if self.model_type == 'classification' and self.reg_type == 'probit':
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/base_layer.py:1014, in Layer.__call__(self, *args, **kwargs)
#    1010   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1012 with autocast_variable.enable_auto_cast_variables(
#    1013     self._compute_dtype_object):
# -> 1014   outputs = call_fn(inputs, *args, **kwargs)
#    1016 if self._activity_regularizer:
#    1017   self._handle_activity_regularization(inputs, outputs)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/layers/core/dense.py:224, in Dense.call(self, inputs)
#     221     outputs = tf.matmul(a=inputs, b=self.kernel)
#     222 # Broadcast kernel to inputs.
#     223 else:
# --> 224   outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#     225   # Reshape the output back to the original ndim of the input.
#     226   if not tf.executing_eagerly():
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:5124, in tensordot(a, b, axes, name)
#    5121 a_reshape, a_free_dims, a_free_dims_static = _tensordot_reshape(a, a_axes)
#    5122 b_reshape, b_free_dims, b_free_dims_static = _tensordot_reshape(
#    5123     b, b_axes, True)
# -> 5124 ab_matmul = matmul(a_reshape, b_reshape)
#    5125 if isinstance(a_free_dims, list) and isinstance(b_free_dims, list):
#    5126   if (ab_matmul.get_shape().is_fully_defined() and
#    5127       ab_matmul.get_shape().as_list() == a_free_dims + b_free_dims):
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:3713, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3710   return gen_math_ops.batch_mat_mul_v3(
#    3711       a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3712 else:
# -> 3713   return gen_math_ops.mat_mul(
#    3714       a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py:6013, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6011 if tld.is_eager:
#    6012   try:
# -> 6013     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6014       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6015       transpose_b)
#    6016     return _result
#    6017   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
res_cs
# Out:
# [[array([2])], [], []]

# %%
with open(os.path.join('data', dir_path, "ESNN.obj"), 'wb') as f:
    pickle.dump(res_cs, f)

# %%
with open(os.path.join('data', dir_path, "ESNN.obj"), 'rb') as f:
    object = pickle.load(f)
object
# Out:
# [[array([3])],
#  [array([5]), array([0])],
#  [array([4])],
#  [array([4]), array([5]), array([0])],
#  [],
#  [array([5]), array([1])],
#  [array([1]), array([4]), array([5])],
#  [array([5]), array([0])],
#  [array([0])],
#  [array([3]), array([0])]]
