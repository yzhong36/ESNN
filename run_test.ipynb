# %%
import tensorflow as tf
import numpy as np
import sys
import random
from scipy.stats import norm
import os
from sklearn.model_selection import train_test_split
from ESNN_layers import *
import pickle

# %%
#load example data
X = np.loadtxt('data/X_reg.txt')
Y = np.loadtxt('data/Y_reg.txt')
X = X.astype('float32')
Y = Y.astype('float32')
sample_size = X.shape[0]
all_indices = range(len(Y))
shuffled_indices = tf.random.shuffle(all_indices)
X, Y= tf.gather(X, shuffled_indices), tf.gather(Y, shuffled_indices)
X, Y=X.numpy(), Y.numpy()
X_train_raw, X_test, Y_train_raw, Y_test = train_test_split(X, Y, test_size=0.15)

# %%
#parameters setup
model_type = 'regression'
reg_type = 'linear'
L = 10 #number of models
nsample = 100 #number of samples used for approximate expectation in ELBO
nepoch =50 #training epoch
input_size = X.shape[1]
if len(Y.shape) == 1:
    output_size = 1
else:
    output_size = Y.shape[1]

initial_size = X.shape[1]
hidden_sizes = [5]# a list of numbers indicate hidden sizes
lamb = 1.0 #weight parameter in loss function
batch_size = 50 
sigma = 0.0001
temperature = 0.1 #for gumbel-softmax trick
tau = 0.3 #for scale alpha in softmax
mini_loss = np.mean(np.square(Y_test-np.mean(Y_test, axis = 0)))*1.0 #this is used as the threshold for purity
l = 0
iteration = 0
max_iter = 15

# %%
#run lasso for init
from sklearn.linear_model import LassoCV
from sklearn.linear_model import MultiTaskLassoCV
if output_size == 1:
    clf = LassoCV(cv=5, random_state=0).fit(X_train_raw, Y_train_raw)
else:
    clf = MultiTaskLassoCV(cv=5, random_state=0, max_iter = 2000).fit(X_train_raw, Y_train_raw)
pred_train = clf.predict(X_train_raw)
acc_train = np.mean((Y_train_raw - pred_train)**2)
pred_test = clf.predict(X_test)
acc_test = np.mean((Y_test - pred_test)**2)
print(f'Lasso Regression| train {acc_train:.4f} test {acc_test:.4f}')
# Out:
# Lasso Regression| train 0.7431 test 0.7057

# %%
####################################NN
##initializations
#if initialize with lasso coefficient
if output_size == 1:
    init_val = np.transpose(abs(clf.coef_))
else:
    init_val = np.mean(np.transpose(abs(clf.coef_)), axis = -1)
init_val = init_val.astype('float32')
init_val = np.reshape(init_val, (input_size, 1))
init_vals = list()
for i in range(L):
    temp_init_val = init_val
    temp_init_val = np.reshape(temp_init_val, (input_size, 1))
    init_vals.append(tf.convert_to_tensor(temp_init_val))
#model
all_model = list()
model = SNN(model_type, reg_type, sigma, input_size, output_size, hidden_sizes, temperature, tau, False, init_vals[0])
all_myloss = list()
all_prbs = list()
all_cs = list()
while l<L and iteration<= max_iter:
    myloss = np.zeros((nepoch, 4))
    for epoch in range(0, nepoch):
        learning_rate = 0.005*(0.995**epoch) # for classification
        model.optimizer = tf.optimizers.Adam(lr = learning_rate)
        all_indices = range(len(Y_train_raw))
        shuffled_indices = tf.random.shuffle(all_indices)
        train_bnn(model, tf.gather(X_train_raw, shuffled_indices), tf.gather(Y_train_raw, shuffled_indices), batch_size, learning_rate, True, nsample, 0.00005, 10.0)#0.00005
        pred, nll, kl = model.call(X_train_raw, Y_train_raw, True, 100)
        if output_size == 1:
            temp_train_acc = np.mean(tf.losses.MSE(pred[:,:,0], Y_train_raw))
        else:
            temp_train_acc = np.mean(tf.losses.MSE(pred, Y_train_raw))
        pred, temp_test_nll, kl = model.call(X_test, Y_test, True, 100)
        if output_size == 1:
            temp_test_acc = np.mean(tf.losses.MSE(pred[:,:,0], Y_test))
        else:
            temp_test_acc = np.mean(tf.losses.MSE(pred, Y_test))
        elbo = nll+kl
        myloss[epoch,0] = elbo
        myloss[epoch,1] = temp_train_acc
        # myloss[epoch,2] = temp_val_acc
        myloss[epoch,2] = temp_test_acc
        print("Iteration", iteration)
        print("Train loss", temp_train_acc)
        print("l", l)
        print("mini loss", mini_loss)
        print("Test loss", temp_test_acc)
        prbs = np.asarray(tf.nn.softmax(model.bnn.w_alpha[:,0]/tau))
        print('#################################################################################################################')
        print(np.where(prbs>0.1))
        print(np.where(prbs == np.max(prbs)))
        if epoch>3 and model_type == 'regression' and temp_test_acc<mini_loss-0.05:
            break
        if epoch>10 and model_type == 'regression' and temp_test_acc<mini_loss-0.01:
            break
        if epoch > 30:
            curr_avg = np.max(myloss[epoch-2:epoch,2])
            pre_avg = np.max(myloss[epoch-4:epoch-2,2])
            if model_type == 'regression' and curr_avg>= pre_avg:
                break
    if model_type == 'regression' and myloss[epoch,2]<=mini_loss-0.01:
        mini_loss = myloss[epoch,2]
        l += 1
        all_myloss.append(myloss)
        all_model.append(model)
        temp_prbs = np.asarray(tf.nn.softmax(model.bnn.w_alpha[:,0]/tau))
        if temp_prbs.shape[0]<initial_size:
            if len(all_cs) == 1:
                toinsert = np.unique(all_cs[0])
            else:
                toinsert = np.unique(np.concatenate(all_cs))
            temp_to_add = temp_prbs
            for pos in toinsert:
                temp_to_add = np.insert(temp_to_add, pos, 1e-10)
            all_prbs.append(temp_to_add)
        else:
            temp_to_add = temp_prbs
            all_prbs.append(temp_to_add)
        #derive residuals
        pred, nll, kl = model.call(X_train_raw, Y_train_raw, True, 100)
        if output_size == 1:
            res_train = np.mean(pred[:,:,0], axis = 0) - Y_train_raw
        else:
            res_train = np.mean(pred, axis = 0) - Y_train_raw
        pred, temp_test_nll, kl = model.call(X_test, Y_test, True, 100)
        if output_size == 1:
            res_test = np.mean(pred[:,:,0], axis = 0) - Y_test
        else:
            res_test = np.mean(pred, axis = 0) - Y_test
        Y_train_raw = res_train
        Y_test = res_test
        #compute cs
        nsnp = temp_prbs.shape[0]
        for temp_j in range(nsnp):
            cs_idx = nsnp-temp_j
            if sum(np.sort(temp_prbs)[cs_idx:])>0.95:
                break
        temp_cs = np.argsort(temp_prbs)[cs_idx:]
        if temp_cs.shape[0]>1:
            cc = np.corrcoef(np.transpose(X[:,temp_cs]))
            for k in range(cc.shape[0]):
                cc[k][k]=0.5
        else:
            cc = 0.5
        if np.min(cc)>=0.5:
            # all_cs.append(temp_cs)
            #remove found variables
            X_train_raw = np.delete(X_train_raw, temp_cs, axis = 1)
            X_test = np.delete(X_test, temp_cs, axis = 1)
            input_size = X_train_raw.shape[1]
            #add cs with correct idx
            nsnp = temp_to_add.shape[0]
            for temp_j in range(nsnp):
                cs_idx = nsnp-temp_j
                if sum(np.sort(temp_to_add)[cs_idx:])>0.95:
                    break
            temp_cs = np.argsort(temp_to_add)[cs_idx:]
            all_cs.append(temp_cs)
    if len(all_cs)>0:
        temp_init_val = tf.random.truncated_normal([input_size, 1], mean=0.0, stddev=0.1, dtype=tf.dtypes.float32)
    else:
        temp_init_val = init_vals[0]
    model = SNN(model_type, reg_type, sigma, input_size, output_size, hidden_sizes, temperature, tau, False, temp_init_val)
    iteration+=1
# Out:
# /Users/yzhong36/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Iteration 0
# Train loss 1.2711823
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2286781
# #################################################################################################################
# (array([], dtype=int64),)
# (array([53]),)
# Iteration 0
# Train loss 1.058028
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0436525
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.1758631
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2014663
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.1995499
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1968491
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2753196
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2543522
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2301344
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2136858
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2562884
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2454954
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2847787
# l 0
# mini loss 0.9860114455223083
# Test loss 1.277695
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2911688
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2802643
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.267598
# l 0
# mini loss 0.9860114455223083
# Test loss 1.257964
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2560363
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2480234
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2813146
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2627076
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2365004
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2258415
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.283625
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2694942
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2700678
# l 0
# mini loss 0.9860114455223083
# Test loss 1.249859
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2610747
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2491523
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2351209
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2227112
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2518637
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2496917
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.225785
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2199582
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2275844
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2142353
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2873603
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2753383
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2888622
# l 0
# mini loss 0.9860114455223083
# Test loss 1.276437
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2705512
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2651987
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2240326
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2132344
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2321787
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2237823
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2326736
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2220398
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2583708
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2480484
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2074308
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1935992
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.260048
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2543765
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2543389
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2417209
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2593685
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2418883
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2646277
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2554202
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 0
# Train loss 1.2442886
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2325492
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.0869919
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0658462
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.1952522
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1896974
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2120255
# l 0
# mini loss 0.9860114455223083
# Test loss 1.197555
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2318226
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2147479
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2646819
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2443812
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2168067
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2068132
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2963457
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2736647
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2453457
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2321192
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.253909
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2409242
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.260559
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2459159
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2461003
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2357575
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2783234
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2592163
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2424589
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2271416
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2768828
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2586558
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2596846
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2433236
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2506053
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2371193
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2509009
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2460579
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2682912
# l 0
# mini loss 0.9860114455223083
# Test loss 1.257409
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.269885
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2560406
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2415191
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2298355
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2775388
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2606415
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2880138
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2669867
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2554716
# l 0
# mini loss 0.9860114455223083
# Test loss 1.242475
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2510111
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2324336
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2456509
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2282357
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.258794
# l 0
# mini loss 0.9860114455223083
# Test loss 1.246059
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.255385
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2389969
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2624319
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2459778
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.3149393
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2979633
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.3288375
# l 0
# mini loss 0.9860114455223083
# Test loss 1.3112319
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2462018
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2315193
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 1
# Train loss 1.2461053
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2343657
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.0952553
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0788208
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.1850038
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2143154
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2748301
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2626245
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2250811
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2059692
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2145362
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2015482
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2485647
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2443197
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2327762
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2183921
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2683451
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2552154
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2837375
# l 0
# mini loss 0.9860114455223083
# Test loss 1.273053
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2433922
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2282246
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2403663
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2294825
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2863802
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2725561
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2599063
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2531112
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.3052266
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2826196
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2831613
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2658331
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.3083811
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2911676
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2219231
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2134261
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2508825
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2348278
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2304811
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2208298
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2602805
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2392175
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.3249981
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2965862
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2685037
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2590742
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2908584
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2766837
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.256025
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2439272
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2972867
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2819061
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2584413
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2481915
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2879272
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2749577
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2662771
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2543913
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2931794
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2801867
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2987287
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2823265
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2961197
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2795756
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 2
# Train loss 1.2447294
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2329137
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.1473367
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1339934
# #################################################################################################################
# (array([96]),)
# (array([96]),)
# Iteration 3
# Train loss 1.0555977
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0462637
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2015457
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1900334
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.186297
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1715713
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2603241
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2419151
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2388183
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2193131
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2517437
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2503924
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2822378
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2677089
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2470106
# l 0
# mini loss 0.9860114455223083
# Test loss 1.226335
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2624778
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2450416
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2468135
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2269938
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2034241
# l 0
# mini loss 0.9860114455223083
# Test loss 1.181013
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2783973
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2586277
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2237983
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2142407
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2641091
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2460214
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2433022
# l 0
# mini loss 0.9860114455223083
# Test loss 1.231072
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.237149
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2247757
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2518952
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2405351
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2858998
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2721419
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.274025
# l 0
# mini loss 0.9860114455223083
# Test loss 1.262808
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2560933
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2413263
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2627866
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2469207
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.248795
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2424523
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2524838
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2353328
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2605201
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2495382
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2695774
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2537658
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2632241
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2476386
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2880907
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2721736
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2424814
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2291434
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2403326
# l 0
# mini loss 0.9860114455223083
# Test loss 1.223377
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2564596
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2470486
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2606655
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2498268
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 3
# Train loss 1.2431227
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2294718
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.0919615
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0749998
# #################################################################################################################
# (array([], dtype=int64),)
# (array([18]),)
# Iteration 4
# Train loss 1.0064197
# l 0
# mini loss 0.9860114455223083
# Test loss 0.9926505
# #################################################################################################################
# (array([39, 82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.138662
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1046059
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.1924927
# l 0
# mini loss 0.9860114455223083
# Test loss 1.150893
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.1804081
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1508527
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2350745
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2177206
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2225758
# l 0
# mini loss 0.9860114455223083
# Test loss 1.202881
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2530228
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2471117
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2622963
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2512777
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2376188
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2285
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2891167
# l 0
# mini loss 0.9860114455223083
# Test loss 1.27408
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2702795
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2595102
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2391835
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2248187
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.234269
# l 0
# mini loss 0.9860114455223083
# Test loss 1.225578
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2729231
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2551064
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2154602
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2055165
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2768778
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2606045
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2382308
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2250333
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.301769
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2834462
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2451774
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2309268
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2900164
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2758305
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2757736
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2568903
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2442254
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2321122
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2606603
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2468282
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2655243
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2523056
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2055675
# l 0
# mini loss 0.9860114455223083
# Test loss 1.194009
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2617167
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2522858
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.259986
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2434924
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2680341
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2583025
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2480544
# l 0
# mini loss 0.9860114455223083
# Test loss 1.239545
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2555526
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2403499
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2973062
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2837608
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 4
# Train loss 1.2528076
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2358705
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.0541188
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0321652
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.1680926
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1438199
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.258862
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2544292
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2469164
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2463841
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2495687
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2578205
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2566173
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2349523
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2246485
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2098289
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2561826
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2408911
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2357767
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2207098
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2606016
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2486424
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.1941148
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1855079
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2803093
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2666419
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.3065263
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2865967
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2500868
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2333752
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2961802
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2864128
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2949965
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2857926
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2561543
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2442298
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.3123429
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2918671
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2831787
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2728205
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2181995
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2094705
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2315387
# l 0
# mini loss 0.9860114455223083
# Test loss 1.223042
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.294024
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2785301
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2525641
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2392938
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2683141
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2554535
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2389874
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2287906
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2849588
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2669362
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2624122
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2534542
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.249779
# l 0
# mini loss 0.9860114455223083
# Test loss 1.240494
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2498327
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2359245
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2775191
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2676741
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2530769
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2407901
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 5
# Train loss 1.2821966
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2676964
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.040396
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0225618
# #################################################################################################################
# (array([], dtype=int64),)
# (array([99]),)
# Iteration 6
# Train loss 1.0621368
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0624491
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.1563946
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1531798
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2140799
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2037615
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2338442
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2380967
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2305645
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2181304
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2260461
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2151711
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.3017665
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2916987
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2366431
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2274206
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2018783
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1902704
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2672061
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2502682
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2260102
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2159111
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 6
# Train loss 1.2482624
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2399213
# ...
# (array([82]),)
# (array([82]),)
# Iteration 13
# Train loss 1.2791119
# l 0
# mini loss 0.9860114455223083
# Test loss 1.26534
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 13
# Train loss 1.2508254
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2365601
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.0435872
# l 0
# mini loss 0.9860114455223083
# Test loss 1.0269437
# #################################################################################################################
# (array([87]),)
# (array([87]),)
# Iteration 14
# Train loss 1.0027924
# l 0
# mini loss 0.9860114455223083
# Test loss 0.9909069
# #################################################################################################################
# (array([57, 87]),)
# (array([57]),)
# Iteration 14
# Train loss 1.1481599
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1175843
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2349832
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2201614
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2084272
# l 0
# mini loss 0.9860114455223083
# Test loss 1.199793
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.27159
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2185479
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2100403
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1929353
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2905228
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2669091
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2728623
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2602004
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.3018088
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2849395
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2511847
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2388555
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2871238
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2733198
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2415503
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2261591
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2420888
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2262591
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2647676
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2483654
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2195965
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2093544
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2491546
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2366136
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2542529
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2417752
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.221574
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2183757
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.1994159
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1910847
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2806022
# l 0
# mini loss 0.9860114455223083
# Test loss 1.267381
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.290861
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2737346
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2519956
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2490097
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2085931
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1996186
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.241548
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2234327
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.256133
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2405072
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2267618
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2093414
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2532961
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2371886
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.3016473
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2804301
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2205952
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2093217
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2523932
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2345812
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2256011
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2152439
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2577453
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2436259
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 14
# Train loss 1.2698514
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2530192
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.1375754
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1261343
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2260847
# l 0
# mini loss 0.9860114455223083
# Test loss 1.1929889
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.216872
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2142578
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2574557
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2460682
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2253226
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2008581
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2324083
# l 0
# mini loss 0.9860114455223083
# Test loss 1.218108
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2523683
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2321938
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.292021
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2693954
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2417216
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2265868
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.266705
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2549818
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2791785
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2613579
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2573634
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2365873
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2992992
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2940016
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2398624
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2320006
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.3256814
# l 0
# mini loss 0.9860114455223083
# Test loss 1.3091872
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.266048
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2580601
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.3129153
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2946129
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2479606
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2397825
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2633336
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2491485
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2471671
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2372035
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2542561
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2407513
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2305211
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2156011
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.3247201
# l 0
# mini loss 0.9860114455223083
# Test loss 1.3054152
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2105379
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2006905
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.3059101
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2940034
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2288619
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2183337
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2385542
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2263173
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2447594
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2279259
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2495689
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2372428
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2338834
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2187463
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2216575
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2140558
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2765112
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2591451
# #################################################################################################################
# (array([82]),)
# (array([82]),)
# Iteration 15
# Train loss 1.2642916
# l 0
# mini loss 0.9860114455223083
# Test loss 1.2501794
# #################################################################################################################
# (array([82]),)
# (array([82]),)

# %%
np.mean(tf.losses.MSE(pred[1,:,0], Y_test))
# Out:
# 0.70828384

# %%
np.mean(tf.losses.MSE(pred[1], Y_test))
# Out:
# 1.2414048

# %%
pred[1,:,0].shape
# Out:
# TensorShape([750])

# %%
pred[1].shape
# Out:
# TensorShape([750, 1])

# %%
a = np.mean(pred, axis = 0) - Y_test

# %%
b = np.mean(pred[:,:,0], axis = 0) - Y_test

np.mean(a = b)
# Out:
# 0.016114369

# %%
np.subtract(np.mean(pred[:,:,0], axis = 0), Y_test).shape
# Out:
# (750,)

# %%
all_cs
# Out:
# []

# %%
#write data
all_myloss = np.asarray(all_myloss)
all_prbs = np.asarray(all_prbs)
import pickle
all_data = {}
all_data['loss'] = all_myloss
all_data['pips'] = all_prbs
all_data['cs'] = all_cs
